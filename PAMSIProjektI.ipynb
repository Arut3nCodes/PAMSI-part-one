# %% [markdown]
# # 1. Zrozumienie biznesowe (Business Understanding)
#
# ### Kontekst
#
# Dane pochodzą z programu "Measuring Broadband America" prowadzonego przez amerykańską Federalną Komisję Komunikacji (FCC), który mierzy rzeczywistą wydajność szerokopasmowych usług internetowych.
#
# ### Cele analizy:
#
# - Ocena różnicy między deklarowaną a rzeczywistą prędkością internetu
#
# - Identyfikacja czynników wpływających na wydajność łącza
#
# - Analiza stabilności połączeń
#
# ### Metryki:
#
#
# - Identyfikacja zmiennych najbardziej skorelowanych z wydajnością
#
# - Stworzenie czytelnych wizualizacji pokazujących charakterystykę połączeń

# %% [markdown]
# # 2.
#
#
# #### curr_datausage.csv
# | Pole                     | Typ danych | Opis                                                                 | Przykładowa wartość       |
# |--------------------------|------------|----------------------------------------------------------------------|---------------------------|
# | `unit_id`                | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                       |
# | `dtime`                  | datetime   | Data i czas pomiaru                                                 | 2023-01-01 06:32:00       |
# | `sk_tx_bytes`            | integer    | Liczba bajtów wysłanych przez urządzenie SamKnows (transmit)        | 0                         |
# | `sk_rx_bytes`            | integer    | Liczba bajtów odebranych przez urządzenie SamKnows (receive)        | 61288                     |
# | `cust_wired_tx_bytes`    | integer    | Liczba bajtów wysłanych przez klienta przez połączenie przewodowe   | 42114358                  |
# | `cust_wired_rx_bytes`    | integer    | Liczba bajtów odebranych przez klienta przez połączenie przewodowe  | 2190548237                |
# | `cust_wifi_tx_bytes`     | integer    | Liczba bajtów wysłanych przez klienta przez Wi-Fi                   | 0                         |
# | `cust_wifi_rx_bytes`     | integer    | Liczba bajtów odebranych przez klienta przez Wi-Fi                  | 3225217                   |
#
#
#
# curr_dlping.csv
# | Pole             | Typ danych | Opis                                                                 | Przykładowa wartość       |
# |------------------|------------|----------------------------------------------------------------------|---------------------------|
# | `unit_id`        | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                       |
# | `dtime`          | datetime   | Data i czas pomiaru                                                 | 2023-01-01 11:46:44       |
# | `target`         | string     | Adres serwera/docelowy punkt pomiaru opóźnienia                      | newyorkfcc.west.verizon.net |
# | `rtt_avg`        | integer    | Średnie opóźnienie (Round-Trip Time) w milisekundach                 | 8625                      |
# | `rtt_min`        | integer    | Minimalne opóźnienie (RTT) w milisekundach                           | 7036                      |
# | `rtt_max`        | integer    | Maksymalne opóźnienie (RTT) w milisekundach                          | 13951                     |
# | `rtt_std`        | integer    | Odchylenie standardowe opóźnienia (RTT) w milisekundach              | 1269                      |
# | `successes`      | integer    | Liczba udanych prób ping                                             | 164                       |
# | `failures`       | integer    | Liczba nieudanych prób ping                                          | 0                         |
#
#
# curr_dns.csv
# | Pole             | Typ danych | Opis                                                                 | Przykładowa wartość       |
# |------------------|------------|----------------------------------------------------------------------|---------------------------|
# | `unit_id`        | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                       |
# | `dtime`          | datetime   | Data i czas pomiaru                                                 | 2023-01-01 00:46:45       |
# | `nameserver`     | string     | Adres serwera DNS użytego do zapytania                              | 71.243.0.12               |
# | `lookup_host`    | string     | Nazwa domeny, której dotyczy zapytanie DNS                          | www.google.com            |
# | `response_ip`    | string     | Adres IP zwrócony przez serwer DNS                                  | 142.250.176.196           |
# | `rtt`            | integer    | Czas odpowiedzi DNS w milisekundach (Round-Trip Time)               | 4619                      |
# | `successes`      | integer    | Liczba udanych zapytań DNS                                          | 1                         |
# | `failures`       | integer    | Liczba nieudanych zapytań DNS                                       | 0                         |
#
#
# curr_httpgetmt.csv i curr_httppostmt.csv
# | Pole                     | Typ danych | Opis                                                                 | Przykładowa wartość       |
# |--------------------------|------------|----------------------------------------------------------------------|---------------------------|
# | `unit_id`                | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                       |
# | `dtime`                  | datetime   | Data i czas pomiaru                                                 | 2023-01-01 11:46:34       |
# | `target`                 | string     | Docelowy serwer/testowany URL                                       | sp1-vm-newyork-us.samknows.com |
# | `address`                | string     | Adres IP serwera docelowego                                         | 151.139.31.1              |
# | `fetch_time`             | integer    | Całkowity czas pobierania/wysyłania danych                          | 10012065                  |
# | `bytes_total`            | integer    | Całkowita liczba przesłanych bajtów                                 | 256106610                 |
# | `bytes_sec`              | integer    | Prędkość transferu (bajty/sekundę)                                  | 25579799                  |
# | `bytes_sec_interval`     | integer    | Prędkość transferu w określonym przedziale czasowym                 | 25579799                  |
# | `warmup_time`            | integer    | Czas inicjalizacji połączenia                                       | 5026538                   |
# | `warmup_bytes`           | integer    | Bajty przesłane podczas fazy inicjalizacji                          | 122905442                 |
# | `sequence`               | integer    | Numer sekwencji testu (np. kolejność prób)                          | 0                         |
# | `threads`                | integer    | Liczba wątków użytych do testu                                      | 8                         |
# | `successes`              | integer    | Liczba udanych żądań HTTP                                           | 1                         |
# | `failures`               | integer    | Liczba nieudanych żądań HTTP                                        | 0                         |
#
#
# curr_lct_dl.csv i curr_lct_ul.csv
# | Pole                 | Typ danych | Opis                                                                 | Przykładowa wartość       |
# |----------------------|------------|----------------------------------------------------------------------|---------------------------|
# | `unit_id`            | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                       |
# | `ddate`              | date       | Data pomiaru (część daty z `dtime`)                                 | 2023-01-01                |
# | `dtime`              | datetime   | Pełna data i czas pomiaru                                           | 2023-01-01 11:47:19       |
# | `target`             | string     | Docelowy serwer testowy                                             | sp1-vm-newyork-us.samknows.com |
# | `address`            | string     | Adres IP serwera docelowego                                         | 151.139.31.1              |
# | `packets_received`   | integer    | Liczba odebranych pakietów                                          | 52 (dl) / 100 (ul)         |
# | `packets_sent`       | integer    | Liczba wysłanych pakietów                                           | 100                        |
# | `packet_size`        | integer    | Rozmiar pojedynczego pakietu w bajtach                              | 1400                       |
# | `bytes_total`        | integer    | Całkowita liczba przesłanych bajtów                                 | 72800 (dl) / 140000 (ul)   |
# | `duration`           | integer    | Czas trwania testu w milisekundach                                  | 878                        |
# | `bytes_sec`          | integer    | Prędkość transferu (bajty/sekundę)                                  | 85835096                   |
# | `error_code`         | string     | Kod błędu (np. `NO_ERROR` oznacza brak błędów)                      | NO_ERROR                   |
# | `successes`          | integer    | Liczba udanych prób                                                 | 1                          |
# | `failures`           | integer    | Liczba nieudanych prób                                              | 0                          |
#
#
# curr_ping.csv
# | Pole             | Typ danych | Opis                                                                 | Przykładowa wartość       |
# |------------------|------------|----------------------------------------------------------------------|---------------------------|
# | `unit_id`        | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                       |
# | `dtime`          | datetime   | Data i czas pomiaru                                                 | 2023-01-01 00:47:25       |
# | `target`         | string     | Docelowy serwer/testowany punkt pomiaru opóźnienia                   | sp1-vm-newyork-us.samknows.com |
# | `rtt_avg`        | integer    | Średnie opóźnienie (Round-Trip Time) w milisekundach                 | 8288                      |
# | `rtt_min`        | integer    | Minimalne opóźnienie (RTT) w milisekundach                           | 7565                      |
# | `rtt_max`        | integer    | Maksymalne opóźnienie (RTT) w milisekundach                          | 8634                      |
# | `rtt_std`        | integer    | Odchylenie standardowe opóźnienia (RTT) w milisekundach              | 440                       |
# | `successes`      | integer    | Liczba udanych prób ping                                             | 5                         |
# | `failures`       | integer    | Liczba nieudanych prób ping                                          | 0                         |
#
#
# curr_traceroute.csv
# | Pole             | Typ danych | Opis                                                                 | Przykładowa wartość                                                                 |
# |------------------|------------|----------------------------------------------------------------------|-------------------------------------------------------------------------------------|
# | `unit_id`        | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                                                                                 |
# | `dtime`          | datetime   | Data i czas pomiaru                                                 | 2023-01-02 17:56:29                                                                |
# | `target`         | string     | Docelowy serwer/testowany host                                      | sp1-vm-newyork-us.samknows.com                                                     |
# | `address`        | string     | Adres IP serwera docelowego                                         | 151.139.31.1                                                                       |
# | `protocol`       | string     | Protokół użyty do testu (np. UDP, ICMP)                             | UDP                                                                                |
# | `hop`            | integer    | Numer przeskoku (kolejny punkt na trasie do celu)                   | 21                                                                                 |
# | `hop_address`    | string     | Adres IP przeskoku (może być pusty, jeśli nieznany)                 | 72.93.88.1                                                                         |
# | `hop_name`       | string     | Nazwa hosta przeskoku (może być pusta)                              | lo0-100.BSTNMA-VFTTP-345.verizon-gni.net                                           |
# | `sent`           | integer    | Liczba pakietów wysłanych do przeskoku                              | 3                                                                                  |
# | `received`       | integer    | Liczba pakietów odebranych z przeskoku                              | 0                                                                                  |
# | `rtt_avg`        | integer    | Średni czas opóźnienia (RTT) dla przeskoku w milisekundach          | 2780                                                                               |
# | `successes`      | integer    | Liczba udanych prób                                                 | 1                                                                                  |
# | `failures`       | integer    | Liczba nieudanych prób                                              | 0                                                                                  |
#
#
#
# curr_udploss.csv
# | Pole             | Typ danych | Opis                                                                 | Przykładowa wartość                     |
# |------------------|------------|----------------------------------------------------------------------|-----------------------------------------|
# | `unit_id`        | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                                     |
# | `dtime`          | datetime   | Data i czas pomiaru                                                 | 2023-01-21 06:05:08                    |
# | `duration`       | integer    | Czas trwania testu w milisekundach                                  | 4500449                                 |
# | `target`         | string     | Docelowy serwer                                                     | newyorkfcc.west.verizon.net             |
# | `address`        | string     | Adres IP serwera docelowego                                         | 206.124.86.197                          |
# | `packets`        | integer    | Liczba pakietów utraconych podczas testu                            | 2                                       |
#
#
#
# curr_udpjitter.csv
# | Pole                   | Typ danych | Opis                                                                 | Przykładowa wartość       |
# |------------------------|------------|----------------------------------------------------------------------|---------------------------|
# | `unit_id`              | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                       |
# | `dtime`                | datetime   | Data i czas pomiaru                                                 | 2023-01-01 11:41:34       |
# | `target`               | string     | Docelowy serwer                                                     | sp1-vm-newyork-us.samknows.com |
# | `packet_size`          | integer    | Rozmiar pakietu w bajtach                                           | 160                       |
# | `stream_rate`          | integer    | Docelowa prędkość strumienia w bitach na sekundę (bps)              | 64000                     |
# | `duration`             | integer    | Czas trwania testu w mikrosekundach                                 | 15010478                  |
# | `packets_up_sent`      | integer    | Liczba pakietów wysłanych w górę (do serwera)                      | 500                       |
# | `packets_down_sent`    | integer    | Liczba pakietów wysłanych w dół (do klienta)                       | 500                       |
# | `packets_up_recv`      | integer    | Liczba pakietów odebranych w górę                                  | 500                       |
# | `packets_down_recv`    | integer    | Liczba pakietów odebranych w dół                                   | 500                       |
# | `jitter_up`           | integer    | Zmienność opóźnienia (jitter) w górę w mikrosekundach              | 1528                      |
# | `jitter_down`         | integer    | Zmienność opóźnienia (jitter) w dół w mikrosekundach               | 724                       |
# | `latency`             | integer    | Średnie opóźnienie (RTT) w mikrosekundach                          | 8340                      |
# | `successes`           | integer    | Liczba udanych prób                                                 | 1                         |
# | `failures`            | integer    | Liczba nieudanych prób                                              | 0                         |
#
#
#
# curr_udplatency.csv i curr_udptlatency6.csv
# | Pole             | Typ danych | Opis                                                                 | Przykładowa wartość                     |
# |------------------|------------|----------------------------------------------------------------------|-----------------------------------------|
# | `unit_id`        | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386 / 213582                            |
# | `dtime`          | datetime   | Data i czas pomiaru                                                 | 2023-01-01 00:32:57                    |
# | `target`         | string     | Docelowy serwer                                                     | newyorkfcc.west.verizon.net             |
# | `rtt_avg`        | integer    | Średnie opóźnienie (RTT) w milisekundach                            | 8748                                    |
# | `rtt_min`        | integer    | Minimalne opóźnienie (RTT) w milisekundach                          | 7291                                    |
# | `rtt_max`        | integer    | Maksymalne opóźnienie (RTT) w milisekundach                         | 25863                                   |
# | `rtt_std`        | integer    | Odchylenie standardowe opóźnienia (RTT) w milisekundach             | 3190                                    |
# | `successes`      | integer    | Liczba udanych pomiarów                                             | 2208                                    |
# | `failures`       | integer    | Liczba nieudanych pomiarów                                          | 1                                       |
#
#
#
# curr_ulping.csv
# | Pole             | Typ danych | Opis                                                                 | Przykładowa wartość                     |
# |------------------|------------|----------------------------------------------------------------------|-----------------------------------------|
# | `unit_id`        | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                                     |
# | `dtime`          | datetime   | Data i czas pomiaru                                                 | 2023-01-01 11:47:12                    |
# | `target`         | string     | Docelowy serwer                                                     | newyorkfcc.west.verizon.net             |
# | `rtt_avg`        | integer    | Średnie opóźnienie (RTT) w milisekundach                            | 7720                                    |
# | `rtt_min`        | integer    | Minimalne opóźnienie (RTT) w milisekundach                          | 6994                                    |
# | `rtt_max`        | integer    | Maksymalne opóźnienie (RTT) w milisekundach                         | 12152                                   |
# | `rtt_std`        | integer    | Odchylenie standardowe opóźnienia (RTT) w milisekundach             | 929                                     |
# | `successes`      | integer    | Liczba udanych prób ping                                            | 153                                     |
# | `failures`       | integer    | Liczba nieudanych prób ping                                         | 0                                       |
#
#
#
# curr_webget.csv
# | Pole                     | Typ danych | Opis                                                                 | Przykładowa wartość       |
# |--------------------------|------------|----------------------------------------------------------------------|---------------------------|
# | `unit_id`                | integer    | Unikalny identyfikator urządzenia pomiarowego                       | 386                       |
# | `dtime`                  | datetime   | Data i czas pomiaru                                                 | 2023-01-01 11:56:25       |
# | `target`                 | string     | Testowany URL                                                       | http://www.apple.com/     |
# | `address`                | string     | Adres IP serwera (może być pusty w przypadku błędu)                 | 104.88.72.214             |
# | `fetch_time`             | integer    | Całkowity czas pobierania w mikrosekundach                          | 7523005                   |
# | `bytes_total`            | integer    | Sumaryczny rozmiar pobranych danych w bajtach                       | 2622813                   |
# | `bytes_sec`              | integer    | Średnia prędkość pobierania (bajty/sekundę)                         | 348639                    |
# | `objects`                | integer    | Liczba pobranych obiektów (np. obrazów, plików CSS/JS)              | 16                        |
# | `threads`                | integer    | Liczba równoległych wątków użytych do testu                         | 8                         |
# | `requests`               | integer    | Liczba wysłanych żądań HTTP                                         | 16                        |
# | `connections`            | integer    | Liczba otwartych połączeń TCP                                       | 9                         |
# | `reused_connections`     | integer    | Liczba ponownie użytych połączeń TCP                                | 7                         |
# | `lookups`                | integer    | Liczba zapytań DNS wykonanych podczas testu                         | 1                         |
# | `request_total_time`     | integer    | Sumaryczny czas obsługi żądań HTTP w mikrosekundach                 | 46588431                  |
# | `request_min_time`       | integer    | Minimalny czas obsługi pojedynczego żądania                         | 96581                     |
# | `request_avg_time`       | integer    | Średni czas obsługi żądania                                         | 2911776                   |
# | `request_max_time`       | integer    | Maksymalny czas obsługi żądania                                     | 6482799                   |
# | `ttfb_total`             | integer    | Sumaryczny czas "Time To First Byte" (TTFB) w mikrosekundach        | 40169228                  |
# | `ttfb_min`               | integer    | Minimalny TTFB                                                      | 680799                    |
# | `ttfb_avg`               | integer    | Średni TTFB                                                         | 4463247                   |
# | `ttfb_max`               | integer    | Maksymalny TTFB                                                     | 4950024                   |
# | `lookup_total_time`      | integer    | Sumaryczny czas zapytań DNS w mikrosekundach                        | 5562                      |
# | `lookup_min_time`        | integer    | Minimalny czas zapytania DNS                                        | 5562                      |
# | `lookup_avg_time`        | integer    | Średni czas zapytania DNS                                           | 5562                      |
# | `lookup_max_time`        | integer    | Maksymalny czas zapytania DNS                                       | 5562                      |
# | `successes`              | integer    | Liczba udanych pobrań                                               | 1                         |
# | `failures`               | integer    | Liczba nieudanych pobrań                                            | 0                         |

# %% [markdown]
# | Nazwa pliku              | Opis                                                                                          | Kluczowe parametry                                                                 |
# |--------------------------|-----------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------|
# | `curr_datausage.csv`     | Zapis transferu danych (wysłane/odebrane bajty) dla urządzenia SamKnows oraz klienta (przewód/Wi-Fi). | `sk_tx_bytes`, `cust_wired_rx_bytes`, `cust_wifi_tx_bytes`                        |
# | `curr_dlping.csv`        | Testy opóźnienia (ping) dla połączeń **download** do serwerów docelowych.                     | `rtt_avg`, `rtt_min`, `rtt_max`, `target`                                         |
# | `curr_httpgetmt.csv`     | Wydajność pobierania danych (**HTTP GET**)               | `bytes_sec`, `fetch_time`, `target`                                    |
# | `curr_httppostmt.csv`    | Wydajność wysyłania danych (**HTTP POST**)                 | `bytes_sec`, `warmup_bytes`                                           |
# | `curr_dns.csv`           | Wyniki zapytań DNS (czas odpowiedzi, adres IP serwera).                                       | `lookup_host`, `response_ip`, `rtt`                                               |
# | `curr_lct_dl.csv`        | Test przepustowości (**download**) z pomiarem utraty pakietów i czasu trwania.   Wygenerowal czat, sam info nie znalazłem            | `bytes_sec`, `packets_received`, `duration`                                       |
# | `curr_lct_ul.csv`        | Test przepustowości (**upload**) z pomiarem utraty pakietów i czasu trwania.       Wygenerowal czat, sam info nie znalazłem             | `bytes_sec`, `packets_sent`, `duration`                                           |
# | `curr_ping.csv`          | Podstawowe testy opóźnienia (ping) do wybranych serwerów.                                     | `rtt_avg`, `rtt_std`, `target`                                                    |
# | `curr_traceroute.csv`    | Ścieżka routingu do docelowego serwera z pomiarem opóźnień na każdym przeskoku.               | `hop`, `hop_address`, `rtt_avg`                                                   |
# | `curr_udploss.csv`       | Pomiar utraty pakietów UDP w określonym przedziale czasowym.                                   | `packets` (utracone pakiety), `duration`                                          |
# | `curr_udpjitter.csv`     | Test zmienności opóźnienia (**jitter**) dla strumieni UDP w obu kierunkach.                   | `jitter_up`, `jitter_down`, `latency`                                             |
# | `curr_udplatency.csv`    | Opóźnienia (**RTT**) dla połączeń UDP (IPv4).                                                 | `rtt_avg`, `rtt_std`, `target`                                                    |
# | `curr_udptlatency6.csv`  | Opóźnienia (**RTT**) dla połączeń UDP (IPv6).                                                 | `rtt_avg`, `rtt_std`, `target`                                                    |
# | `curr_ulping.csv`        | Testy opóźnienia (ping) dla połączeń **upload**.                                              | `rtt_avg`, `rtt_min`, `target`                                                    |
# | `curr_webget.csv`        | Symulacja pobierania zasobów strony WWW (obrazy, skrypty) z metrykami czasu odpowiedzi.       | `ttfb_avg`, `objects`, `bytes_sec`, `reused_connections`                          |

# %% [markdown]
# ![pliki.png](attachment:pliki.png)

# %% [markdown]
# ![]((https://prnt.sc/3KdT4XawOOwe))
